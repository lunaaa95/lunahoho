# %%
import numpy as np
import pandas as pd

df = pd.read_excel('./data/fund_stock.xlsx', index_col=0)
df = df.dropna(axis=0,how='any')
df = df[~(df['1'].isin([0]))]
df.to_excel('./data/clean_fund_stock.xlsx', index=False, header=True)
